# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys

GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/spotify_project'
print(os.listdir(GOOGLE_DRIVE_PATH))
os.chdir(GOOGLE_DRIVE_PATH)
# Out:
# ['naive_bayes_recommender.py', 'naive_bayes_f1.png', 'README.md', 'requirements.txt', 'naive_bayes_conf.png', 'naive_bayes_sample_output.txt', '.gitignore', 'train_and_test_emotionsNB.py', 'spotify_dataset.py', 'emotions_dataset_tfidf.py', '.git', 'data', 'model', 'bert_emotion_performance.txt', 'images', 'final_spotify_poster.pdf', 'runBERT.ipynb', 'train_and_test_emotionBERT.py', 'bert_recommender.py']

# %%
# !python train_and_test_emotionBERT.py
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training: 100% 1000/1000 [05:52<00:00,  2.84it/s]
# Training loss for epoch 0: 0.47604450592584907
# Evaluating: 100% 125/125 [00:16<00:00,  7.66it/s]
# Validation Report:               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       275
#            1       0.95      0.82      0.88       212
#            2       0.97      0.93      0.95       704
#            3       0.80      0.97      0.88       178
#            4       0.94      0.97      0.96       550
#            5       0.85      0.88      0.86        81
#
#     accuracy                           0.93      2000
#    macro avg       0.91      0.92      0.91      2000
# weighted avg       0.94      0.93      0.93      2000
#
# Evaluating: 100% 125/125 [00:16<00:00,  7.76it/s]
# Test Report:               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       275
#            1       0.94      0.84      0.89       224
#            2       0.97      0.93      0.95       695
#            3       0.78      0.97      0.86       159
#            4       0.96      0.97      0.97       581
#            5       0.72      0.82      0.77        66
#
#     accuracy                           0.93      2000
#    macro avg       0.88      0.91      0.89      2000
# weighted avg       0.94      0.93      0.93      2000
#
# Training: 100% 1000/1000 [05:52<00:00,  2.84it/s]
# Training loss for epoch 1: 0.1365733643202111
# Evaluating: 100% 125/125 [00:16<00:00,  7.63it/s]
# Validation Report:               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95       275
#            1       0.91      0.87      0.89       212
#            2       0.95      0.96      0.96       704
#            3       0.90      0.83      0.87       178
#            4       0.95      0.98      0.97       550
#            5       0.84      0.85      0.85        81
#
#     accuracy                           0.94      2000
#    macro avg       0.92      0.91      0.91      2000
# weighted avg       0.94      0.94      0.94      2000
#
# Evaluating: 100% 125/125 [00:16<00:00,  7.70it/s]
# Test Report:               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       275
#            1       0.90      0.90      0.90       224
#            2       0.94      0.97      0.95       695
#            3       0.88      0.77      0.83       159
#            4       0.96      0.98      0.97       581
#            5       0.79      0.74      0.77        66
#
#     accuracy                           0.93      2000
#    macro avg       0.90      0.88      0.89      2000
# weighted avg       0.93      0.93      0.93      2000
#
# Training: 100% 1000/1000 [05:52<00:00,  2.83it/s]
# Training loss for epoch 2: 0.09902497902023606
# Evaluating: 100% 125/125 [00:16<00:00,  7.62it/s]
# Validation Report:               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       275
#            1       0.84      0.93      0.88       212
#            2       0.99      0.91      0.95       704
#            3       0.81      0.96      0.88       178
#            4       0.97      0.96      0.96       550
#            5       0.83      0.84      0.83        81
#
#     accuracy                           0.93      2000
#    macro avg       0.90      0.92      0.91      2000
# weighted avg       0.94      0.93      0.93      2000
#
# Evaluating: 100% 125/125 [00:16<00:00,  7.77it/s]
# Test Report:               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       275
#            1       0.86      0.93      0.90       224
#            2       0.99      0.92      0.95       695
#            3       0.78      0.94      0.85       159
#            4       0.96      0.96      0.96       581
#            5       0.85      0.70      0.77        66
#
#     accuracy                           0.93      2000
#    macro avg       0.89      0.90      0.89      2000
# weighted avg       0.93      0.93      0.93      2000
#
# [Spotify] Predicting Probabilities: 100% 3604/3604 [11:39<00:00,  5.15it/s]
# Enter a song: Someone Like You
# How many similar songs would you like?: 10
#
# Similar Songs!
# 0: Anxious
# 1: No Self Control
# 2: No Self Control
# 3: Flying Solo
# 4: Gotta Get Away
# 5: Fly Away
# 6: Eight Miles High
# 7: Bring Him Home
# 8: Rain
# 9: More Than Natural
