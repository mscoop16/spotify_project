# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys

GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/spotify_project'
print(os.listdir(GOOGLE_DRIVE_PATH))
os.chdir(GOOGLE_DRIVE_PATH)
# Out:
# ['naive_bayes_recommender.py', 'naive_bayes_f1.png', 'train_and_test_emotionBERT.py', 'README.md', 'requirements.txt', 'naive_bayes_conf.png', 'naive_bayes_sample_output.txt', '.gitignore', 'train_and_test_emotionsNB.py', 'spotify_dataset.py', 'emotions_dataset_tfidf.py', '.git', 'data', 'model', 'runBERT.ipynb']

# %%
# !python train_and_test_emotionBERT.py
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training: 100% 1000/1000 [05:56<00:00,  2.81it/s]
# Training loss for epoch 0: 0.4815612161522731
# Evaluating: 100% 125/125 [00:16<00:00,  7.46it/s]
# Validation Report:               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       275
#            1       0.84      0.93      0.89       212
#            2       0.97      0.93      0.95       704
#            3       0.81      0.93      0.86       178
#            4       0.96      0.98      0.97       550
#            5       0.86      0.78      0.82        81
#
#     accuracy                           0.93      2000
#    macro avg       0.90      0.91      0.90      2000
# weighted avg       0.94      0.93      0.93      2000
#
# Evaluating: 100% 125/125 [00:16<00:00,  7.55it/s]
# Test Report:               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.93       275
#            1       0.85      0.94      0.90       224
#            2       0.98      0.92      0.95       695
#            3       0.76      0.96      0.84       159
#            4       0.96      0.97      0.97       581
#            5       0.81      0.71      0.76        66
#
#     accuracy                           0.93      2000
#    macro avg       0.89      0.90      0.89      2000
# weighted avg       0.93      0.93      0.93      2000
#
# Training: 100% 1000/1000 [05:57<00:00,  2.80it/s]
# Training loss for epoch 1: 0.12949383133882655
# Evaluating: 100% 125/125 [00:16<00:00,  7.46it/s]
# Validation Report:               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       275
#            1       0.89      0.84      0.86       212
#            2       0.94      0.98      0.96       704
#            3       0.94      0.83      0.88       178
#            4       0.95      0.97      0.96       550
#            5       1.00      0.73      0.84        81
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.88      0.91      2000
# weighted avg       0.94      0.94      0.93      2000
#
# Evaluating: 100% 125/125 [00:16<00:00,  7.55it/s]
# Test Report:               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       275
#            1       0.89      0.93      0.91       224
#            2       0.92      0.98      0.95       695
#            3       0.95      0.73      0.83       159
#            4       0.97      0.96      0.96       581
#            5       0.97      0.58      0.72        66
#
#     accuracy                           0.93      2000
#    macro avg       0.94      0.86      0.88      2000
# weighted avg       0.93      0.93      0.93      2000
#
# Training: 100% 1000/1000 [05:57<00:00,  2.80it/s]
# Training loss for epoch 2: 0.0994928853737656
# Evaluating: 100% 125/125 [00:16<00:00,  7.48it/s]
# Validation Report:               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       275
#            1       0.88      0.90      0.89       212
#            2       0.95      0.97      0.96       704
#            3       0.94      0.83      0.88       178
#            4       0.96      0.97      0.96       550
#            5       0.85      0.85      0.85        81
#
#     accuracy                           0.94      2000
#    macro avg       0.92      0.91      0.91      2000
# weighted avg       0.94      0.94      0.94      2000
#
# Evaluating: 100% 125/125 [00:16<00:00,  7.57it/s]
# Test Report:               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       275
#            1       0.89      0.89      0.89       224
#            2       0.93      0.97      0.95       695
#            3       0.89      0.74      0.81       159
#            4       0.98      0.96      0.97       581
#            5       0.71      0.74      0.73        66
#
#     accuracy                           0.93      2000
#    macro avg       0.89      0.88      0.88      2000
# weighted avg       0.93      0.93      0.93      2000
